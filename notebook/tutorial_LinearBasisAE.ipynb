# %% [markdown]
# # LinearBasisAE demo
#
# This notebook builds a small synthetic movie cube and fits the
# `comicsnet.LinearBasisAE` background model with the sparse-mask
# loop.
#
# The synthetic cube contains a smooth time-variable background
# plus a
# moving compact source.  The model sees one complete detector
# frame per optimization step and reconstructs each frame as a
# linear combination of detector-fixed basis images.

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import jax
import astropy.io.fits as fits

from comicsnet import Config, LinearBasisAE, fit

rcParams['image.origin'] = 'lower'
rcParams['legend.frameon'] = False

# %% [markdown]
# ## Demo data
#
# The array shape is `(time, y, x)`.  The size is intentionally small so
# that the notebook runs quickly on CPU.

# %%
cube = fits.open('../data/demo.fits')[0].data
nz, ny, nx = cube.shape

# %%
fig, axes = plt.subplots(2, 3, figsize=(9, 6), sharex=True, sharey=True)

for n, ax in enumerate(axes.flatten()):
  ax.imshow(cube[n], cmap='gray')

fig.supxlabel('X coordinate (pixel)', fontsize=12)
fig.supylabel('Y coordinate (pixel)', fontsize=12)

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Fit LinearBasisAE
#
# The model learns detector-fixed basis images and frame-wise
# coefficients.  Increase `inner_steps`, `outer_steps`, or
# `latent_dim` for real data.
#
# Each frame is encoded using only its pixel values and observation
# weights; no frame number or time coordinate is supplied. Model methods
# use `encode(x, weight)`, `predict(x, weight)`, and
# `model(x, key, weight)`. The `fit(model, cube, config=config)` call
# is unchanged.

# %%
config = Config(
  outer_steps=5,
  inner_steps=10000,
  learning_rate=1.0e-4,
  beta=1.0e-4,
  threshold_sigma=3.0,
  erosion_size=3,
  dilation_size=5,
  seed=1,
)

model_key = jax.random.PRNGKey(2)
model = LinearBasisAE(
  frame_shape=(ny, nx),
  latent_dim=1,
  key=model_key,
)

result = fit(model, cube, config=config)

# %% [markdown]
# The trace of the loss function is illustrated below. The loss is computed on the full cube, but the model sees only one frame per optimization step.

# %%
fig, ax = plt.subplots(figsize=(6, 3))

ax.plot(result.losses[-2000:])

ax.set_xlabel('optimization step', fontsize=12)
ax.set_ylabel('loss', fontsize=12)

fig.tight_layout()
plt.show()

# %%
frame_index = 16

fig, axes = plt.subplots(2, 3, figsize=(10, 6))
items = [
  ('cube', cube[frame_index]),
  ('background', result.background[frame_index]),
  ('residual', result.residual[frame_index]),
  ('mask', result.mask[frame_index]),
  ('sparse', result.sparse[frame_index]),
  ('uncertainty', result.uncertainty[frame_index]),
]

for axis, (title, image) in zip(axes.ravel(), items):
  handle = axis.imshow(image, origin='lower', cmap='viridis')
  axis.set_title(title)
  axis.set_xticks([])
  axis.set_yticks([])
  fig.colorbar(handle, ax=axis, fraction=0.046, pad=0.04)

fig.tight_layout()
plt.show()

# %%
hdul = fits.HDUList([
  fits.PrimaryHDU(data=result.residual),
  fits.ImageHDU(data=result.background, name='MODEL'),
  fits.ImageHDU(data=result.mask.astype('int16'), name='MASK'),
  fits.ImageHDU(data=result.uncertainty, name='ERROR'),
])
hdul.writeto('../data/linearBAE.fits', overwrite=True)

# %%
fig, axes = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

axes[0].imshow(result.model.bias)
axes[1].imshow(result.model.basis[0])

fig.tight_layout()
plt.show()
